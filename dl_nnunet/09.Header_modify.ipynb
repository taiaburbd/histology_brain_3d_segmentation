# %%
from utils.helper import print_nrrd_header_info, read_and_display_json, convert_nifti_to_seg_nrrd, process_all_volumes

# %%
lable_json_path = "/user1/ngmm/tr855969/Desktop/Taiabur/ngmm-nnunet/dataset/nnUNet_raw_data/Dataset002_HCFC1/dataset.json"
data = read_and_display_json(lable_json_path)
labels =  data.get('labels', {})
swapped_dict = {value: key for key, value in labels.items()}
swapped_dict
# Out:
# {0: 'background',
#  1: 'CTX+',
#  2: 'cc+',
#  3: 'CPu',
#  4: 'DG',
#  5: 'HP',
#  6: 'RHP',
#  7: 'A',
#  8: 'ig',
#  9: 'fi',
#  10: 'f',
#  11: 'st',
#  12: 'ic',
#  13: 'och',
#  14: 'ac',
#  15: 'fr',
#  16: 'Hb',
#  17: 'TH',
#  18: 'HY',
#  19: 'MB',
#  20: 'P',
#  21: 'MY',
#  22: 'TCB',
#  23: 'V',
#  24: 'OB'}

# %%
# Specify input and output directories and output extension
input_dir = "/work/shared/ngmm/3Dimage/DL_test/target_seg_pred/"
output_dir = "/work/shared/ngmm/3Dimage/DL_test/prediction_metadata/"
output_extension = "_Segments.seg.nrrd"

# Process all NIfTI volumes in the input directory
process_all_volumes(input_dir, output_dir, output_extension, labels)
# Out:
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2603_left_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2603_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2603_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2604_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2604_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2605_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2605_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2606_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2606_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2608_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2608_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2609_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2607_8bits_cropped_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2609_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2610_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2610_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2611_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2611_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2612_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2612_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2613_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2613_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2614_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2614_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2618_left_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2618_right_0000_Segments.seg.nrrd
# Segmented NRRD file saved to: /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/SID9404_R_cropped_0000_Segments.seg.nrrd

# %%
path = "/work/shared/ngmm/3Dimage/DL_test/source_backgroundremoval/NG2603_left.nrrd"
print_nrrd_header_info(path)
# Out:
# Header Information:
# ITK_InputFilterName: NrrdImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# NRRD_kinds[0]: domain
# NRRD_kinds[1]: domain
# NRRD_kinds[2]: domain
# NRRD_space: left-posterior-superior

# %%
# !head -n 11 /work/shared/ngmm/3Dimage/DL_test/source_backgroundremoval/NG2603_left.nrrd
# Out:
# NRRD0004
# # Complete NRRD file format specification at:
# # http://teem.sourceforge.net/nrrd/format.html
# type: unsigned char
# dimension: 3
# space: left-posterior-superior
# sizes: 325 765 356
# space directions: (-0.014435499999999999,0,0) (0,-0.014435499999999999,0) (0,0,0.014435499999999999)
# kinds: domain domain domain
# encoding: gzip
# space origin: (0.0072416798211634142,5.5143599510192844,-2.5622999668121325)

# %%
# !head -n 11 /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2603_left_Segments.seg.nrrd
# Out:
# NRRD0004
# # Complete NRRD file format specification at:
# # http://teem.sourceforge.net/nrrd/format.html
# type: int
# dimension: 3
# space: left-posterior-superior
# sizes: 325 765 356
# space directions: (1,0,0) (0,1,0) (0,0,1)
# kinds: domain domain domain
# endian: little
# encoding: gzip

# %%
# !head -n 11 /work/shared/ngmm/3Dimage/DL_test/prediction_metadata/NG2603_left_Segments.seg.nrrd
# Out:
# NRRD0004
# # Complete NRRD file format specification at:
# # http://teem.sourceforge.net/nrrd/format.html
# type: int
# dimension: 3
# space: left-posterior-superior
# sizes: 325 765 356
# space directions: (1,0,0) (0,1,0) (0,0,1)
# kinds: domain domain domain
# endian: little
# encoding: gzip
